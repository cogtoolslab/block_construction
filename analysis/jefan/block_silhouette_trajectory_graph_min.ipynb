# %%
import os
import sys
import urllib, io
os.getcwd()
sys.path.append("..")
sys.path.append("../utils")
proj_dir = os.path.abspath('../..')

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))

import numpy as np
import scipy.stats as stats
import pandas as pd
from scipy.spatial import distance
from scipy import ndimage
from random import random
from sklearn.cluster import SpectralBiclustering
import itertools

import pymongo as pm
from collections import Counter
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
from matplotlib import colors

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

import blockworld_helpers as utils
import drawing_utils as drawing
import importlib
import scoring
import rda

#from pyvis.network import Network
import networkx as nx
import plotly.graph_objects as go

import plotly
import plotly.io as pio
pio.orca.config.use_xvfb = True
plotly.io.orca.config.save()

import importlib
import graph as g

# %%
## directory & file hierarchy
proj_dir = os.path.abspath('../..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir = os.path.abspath(os.path.join(os.getcwd(),'..'))
results_dir = os.path.join(analysis_dir,'results')
stim_dir = os.path.join(proj_dir,'stimuli')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
json_dir = os.path.join(results_dir,'json')
exp_dir = os.path.abspath(os.path.join(proj_dir,'experiments'))
png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))
jefan_dir = os.path.join(analysis_dir,'jefan')
will_dir = os.path.join(analysis_dir,'will')
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %% [markdown]
# ### load in data

# %%
iteration_name = 'Exp2Pilot3'
num_trials = 24 #for sanity checks

# %%
# Data already compiled into dataframes in CogSci 2020 Dataframe Generator

# trial_end data
trial_path = os.path.join(csv_dir,'block_silhouette_{}_good.csv'.format(iteration_name))
df = pd.read_csv(trial_path)

# # initial_block data
initial_path = os.path.join(csv_dir,'block_silhouette_initial_{}_good.csv'.format(iteration_name))
dfi = pd.read_csv(initial_path)

# # settled_block data
settled_path = os.path.join(csv_dir,'block_silhouette_settled_{}_good.csv'.format(iteration_name))
dfs = pd.read_csv(settled_path)

# # Sanity Check- same participants in each dataset.
df_participants = df.gameID.unique()
dfs_participants = dfs.gameID.unique()
assert Counter(df_participants) == Counter(dfs_participants)

n_before_outliers = len(df_participants)
print(str(n_before_outliers) + ' participants total')
# Out:
# 49 participants total

# %% [markdown]
# ### apply preprocessing

# %%
targets = np.sort(df['targetName'].unique())
ppts = np.sort(df['gameID'].unique())
reps = np.sort(df['repetition'].unique())

dfi['usableDiscreteWorld'] = dfi['discreteWorld'].apply(lambda a: 1+(-1)*np.array(ast.literal_eval(a)))
dfi['flatDiscreteWorld'] = dfi['discreteWorld'].apply(lambda a: (1+(-1)*np.array(ast.literal_eval(a))).flatten())

dfic = dfi.copy()
#dfic = dfi[dfi.condition=='repeated']
dfic = dfic[['targetName','gameID','blockNum','repetition','phase_extended','flatDiscreteWorld','usableDiscreteWorld','rawF1DiscreteScore']]
dfic['discreteWorld'] = dfic['usableDiscreteWorld']
dfic['flatDiscreteWorldStr'] = dfic['flatDiscreteWorld'].apply(convert_to_str)

max_actions = dfic['blockNum'].max()

# %% [markdown]
# ### make trajectory graph

# %%
importlib.reload(g) ## reimport graph utils
phases = ['pre', 'post']
for this_target in targets:
    for this_phase in phases:
        g.plot_trajectory_graph(data = dfic, 
                                target = this_target, 
                                phase = this_phase, 
                                save=False, 
                                extension = 'test',
                                x_lower_bound = 4,
                                x_upper_bound = 13,
                                edge_width_scale_factor = 0.8,
                                node_size_scale_factor = 0.8)
# Out:
# /home/jefan/anaconda3/lib/python3.7/site-packages/scipy/ndimage/measurements.py:1359: RuntimeWarning:
#
# invalid value encountered in double_scalars
# <div>
#
#
#             <div id="a38f1a8c-8c50-4045-bf4a-07ecdad167a7" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a38f1a8c-8c50-4045-bf4a-07ecdad167a7")) {
#                     Plotly.newPlot(
#                         'a38f1a8c-8c50-4045-bf4a-07ecdad167a7',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.07142857142857144]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 21.6}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 12.5], "y": [0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 12.5], "y": [0, 0.06666666666666668]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 9.600000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.14285714285714288]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 7.5], "y": [0, 0.14285714285714288]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 7.5], "y": [0, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.2]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 8.833333333333334], "y": [0.07142857142857144, 0.25]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [12.5, 9.833333333333334], "y": [0.0, 0.1875]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 4.800000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 7.833333333333333], "y": [0.14285714285714288, 0.375]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [10.5, 10.5], "y": [0.14285714285714288, 0.375]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.0], "y": [0.14285714285714288, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 7.166666666666667], "y": [0.14285714285714288, 0.3125]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [7.5, 8.333333333333334], "y": [0.14285714285714288, 0.20689655172413796]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [7.5, 9.0], "y": [0.14285714285714288, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [7.5, 6.5], "y": [0.14285714285714288, 0.2666666666666667]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.833333333333334, 8.071428571428571], "y": [0.25, 0.4444444444444444]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [9.833333333333334, 11.357142857142858], "y": [0.1875, 0.2777777777777778]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [7.833333333333333, 7.75], "y": [0.375, 0.42424242424242425]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 7.2}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [7.833333333333333, 9.357142857142858], "y": [0.375, 0.5555555555555556]}, {"hoverinfo": "none ...
# <div>
#
#
#             <div id="b7b923f2-1125-4e86-a26c-dd28895516ea" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b7b923f2-1125-4e86-a26c-dd28895516ea")) {
#                     Plotly.newPlot(
#                         'b7b923f2-1125-4e86-a26c-dd28895516ea',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 4.5], "y": [0, 0.13333333333333336]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width":
class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41cb64d0-9523-4c34-a53e-b8ed1c065bb9")) {
#                     Plotly.newPlot(
#                         '41cb64d0-9523-4c34-a53e-b8ed1c065bb9',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 13.600000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 14.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 12.5], "y": [0, 0.14285714285714285]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 7.5], "y": [0, 0.21428571428571427]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 4.5], "y": [0, 0.14285714285714285]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 10.3], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 11.200000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [6.5, 8.5], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.5, 7.5], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.5, 6.0], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.5, 6.0], "y": [0.2857142857142857, 0.27586206896551724]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 11.200000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 8.5], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 8.5], "y": [0.2857142857142857, 0.4375000000000001]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 12.3], "y": [0.2857142857142857, 0.25]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 11.0], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 11.5], "y": [0.2857142857142857, 0.26666666666666666]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 8.5], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 7.3], "y": [0.2857142857142857, 0.4375000000000001]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 8.0], "y": ...
# <div>
#
#
#             <div id="abe59415-d914-4bfb-80f3-4730eb87379e" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("abe59415-d914-4bfb-80f3-4730eb87379e")) {
#                     Plotly.newPlot(
#                         'abe59415-d914-4bfb-80f3-4730eb87379e',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 12.5], "y": [0, 0.14285714285714285]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 12.0}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 18.400000000000002}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 7.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.2857142857142857]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.21428571428571427]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.21428571428571427]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [12.5, 9.0], "y": [0.14285714285714285, 0.375]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 12.8}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [6.5, 8.5], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 17.6}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 8.5], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 11.0], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.7], "y": [0.2857142857142857, 0.4375000000000001]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.0], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 6.7], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 7.5], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 8.5], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [9.5, 8.5], "y": [0.2857142857142857, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [5.5, 6.7], "y": [0.2857142857142857, 0.5]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 8.5], "y": [0.21428571428571427, 0.375]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "li ...
# <div>
#
#
#             <div id="1fc4a800-af1a-40e0-a843-cb768d6e0f9a" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1fc4a800-af1a-40e0-a843-cb768d6e0f9a")) {
#                     Plotly.newPlot(
#                         '1fc4a800-af1a-40e0-a843-cb768d6e0f9a',
# ...
# <div>
#
#
#             <div id="fae873e1-853c-4f06-b1ad-68f25e404ca5" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fae873e1-853c-4f06-b1ad-68f25e404ca5")) {
#                     Plotly.newPlot(
#                         'fae873e1-853c-4f06-b1ad-68f25e404ca5',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 24.8}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 9.5], "y": [0, 0.32]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.32]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 6.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 5.0], "y": [0, 0.0909090909090909]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 8.5], "y": [0, 0.24]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.933333333333334], "y": [0, 0.430379746835443]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 6.0], "y": [0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.16]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 4.0], "y": [0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 8.0], "y": [0, 0.0909090909090909]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [9.5, 10.0], "y": [0.32, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 7.2}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [9.5, 8.6], "y": [0.32, 0.3846153846153846]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 10.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [9.5, 9.8], "y": [0.32, 0.3846153846153846]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [9.5, 9.0], "y": [0.32, 0.4444444444444445]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [9.5, 8.8], "y": [0.32, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 8.5], "y": [0.32, 0.5517241379310345]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 9.0], "y": [0.32, 0.4444444444444445]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.5, 6.6], "y": [0.32, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 7.6], "y": [0.24, 0.23076923076923075]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [9.5, 9.5], "y": [0.0, 0.14814814814814814]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 10.2], "y": [0.16, 0.23076923076923075]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [4.0, 6.076923076923077], "y": [0.0, 0.27586206896551724]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [10.0, 10.571428571428571], "y": [0.3076923076923077, 0.2962962962962963]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.0, 9.571428571428571], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": ...
# <div>
#
#
#             <div id="777d18c8-1c60-45c4-8dab-3228a6e20ef2" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("777d18c8-1c60-45c4-8dab-3228a6e20ef2")) {
#                     Plotly.newPlot(
#                         '777d18c8-1c60-45c4-8dab-3228a6e20ef2',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 13.5], "y": [0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 14.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 12.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.16666666666666669]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 6.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.08695652173913045]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [8.5, 4.5], "y": [0, 0.043478260869565216]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.08695652173913045]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 4.0}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.16666666666666669]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [13.5, 13.5], "y": [0.0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.8], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 6.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 10.8], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.5], "y": [0.3076923076923077, 0.42857142857142855]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 4.0}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 11.5], "y": [0.3076923076923077, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.5], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.7], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 10.5], "y": [0.3076923076923077, 0.5333333333333333]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [12.5, 12.5], "y": [0.15384615384615385, 0.26666666666666666]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [12.5, 13.5], "y": [0.15384615384615385, 0.13333333333333333]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.625, 8.583333333333334], "y": [0.3076923076923077, 0.5333333333333333]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [11.5, 11.2], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity ...
# <div>
#
#
#             <div id="c7fe3629-baec-4625-88ff-bf108889c68e" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7fe3629-baec-4625-88ff-bf108889c68e")) {
#                     Plotly.newPlot(
#                         'c7fe3629-baec-4625-88ff-bf108889c68e',
#                         [{"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 10.4}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.16666666666666669]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 11.200000000000001}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 10.5], "y": [0, 0.3076923076923077]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [8.5, 6.5], "y": [0, 0.08695652173913045]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 7.2}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [8.5, 5.5], "y": [0, 0.08695652173913045]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 11.5], "y": [0, 0.16666666666666669]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 3.2}, "mode": "lines", "opacity": 0.7, "type": "scatter", "x": [8.5, 7.0], "y": [0, 0.08695652173913045]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 4.5], "y": [0, 0.043478260869565216]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 13.5], "y": [0, 0.0]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [8.5, 9.5], "y": [0, 0.15384615384615385]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 10.5], "y": [0.3076923076923077, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [11.5, 11.2], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [8.375, 7.9], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 2.4000000000000004}, "mode": "lines", "opacity": 0.5, "type": "scatter", "x": [10.5, 11.5], "y": [0.3076923076923077, 0.4]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 8.8}, "mode": "lines", "opacity": 0.95, "type": "scatter", "x": [10.5, 10.8], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.5], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [10.5, 9.7], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.0, 5.8], "y": [0.2692307692307692, 0.25925925925925924]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 1.6}, "mode": "lines", "opacity": 0.3, "type": "scatter", "x": [6.0, 6.2], "y": [0.2692307692307692, 0.33333333333333337]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [9.625, 9.1], "y": [0.3076923076923077, 0.3703703703703704]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.375, 7.428571428571429], "y": [0.3076923076923077, 0.35714285714285715]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", "width": 0.8}, "mode": "lines", "opacity": 0.1, "type": "scatter", "x": [6.375, 8.727272727272727], "y": [0.3076923076923077, 0.5333333333333333]}, {"hoverinfo": "none", "line": {"color": "#2e2e2e", " ...
