# %%
import os
import sys
import urllib, io
import pickle

import numpy as np
import scipy.stats as stats
import pandas as pd

import pymongo as pm
from collections import Counter
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 
from IPython.core.display import HTML 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

sys.path.append("../../stimuli/block_utils/")
import blockworld_utils as utils

# %%
experiment_name = 'zipping'

## directory & file hierarchy
proj_dir = os.path.abspath('../..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir = os.path.abspath(os.path.join(os.getcwd(),'..'))
results_dir = os.path.join(proj_dir,'results')

# paths specific to this experiment
experiment_results_dir = os.path.join(results_dir, experiment_name)
plot_dir = os.path.join(experiment_results_dir,'plots')
csv_dir = os.path.join(experiment_results_dir,'csv')
json_dir = os.path.join(experiment_results_dir,'json')

png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))
jefan_dir = os.path.join(analysis_dir,'jefan')
will_dir = os.path.join(analysis_dir,'will')

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %%
# plot setup
plt.rcParams["figure.figsize"] = (6,4)

# %% [markdown]
# ### Read csvs

# %%
df_zip_prepost =  pd.read_csv('../results/zipping/csv/df_zip_{}.csv'.format('pre_post_run_0'))

# %%
df_zip_postonly = pd.read_csv('../results/zipping/csv/df_zip_{}.csv'.format('post_run_0'))

# %%
df_zip_versions = df_zip_prepost.append(df_zip_postonly)

# %%
df_zip = df_zip_versions

# %% [markdown]
# ### Helper functions

# %%
def compatibility_diff(df, compatibilities=['compatible','incompatible']):
    '''
    Returns difference between compatibility conditions for response correct and rt (second minus first)
    '''
    diffs = df[df.compatibility==compatibilities[1]][['response_correct','rt']].iloc[0] - df[df.compatibility==compatibilities[0]][['response_correct','rt']].iloc[0] 
    
    
    diffs = diffs.rename({'response_correct':'diff_response_correct',
                                'rt':'diff_rt'})
    
    return diffs

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Analysis setup

# %%
block_order = ['pre_0', 'pre_1', 'post_0', 'post_1']
phase_order = ['pre_zipping_trials', 'post_zipping_trials']

# %% [markdown]
# ### plot setup

# %%
sns.set_context('poster')
sns.set(font_scale=1.2)
sns.set_style('whitegrid', {'font.family':'sans-serif', 'font.sans-serif':'Avenir'})

# %% [markdown]
# ## zipping trials- group level performance

# %%
plt.figure(figsize=(20,10))
sns.distplot(np.log(df_zip[df_zip.compatibility == 'compatible'].rt), rug=True, hist=False)
sns.distplot(np.log(df_zip[df_zip.compatibility == 'incompatible'].rt), rug=True, hist=False)
sns.distplot(np.log(df_zip[df_zip.compatibility == 'novel'].rt), rug=True, hist=False)
plt.xlabel('log(RT)')
# Out:
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/will/opt/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'log(RT)')

# %%
compatibility_order = ["novel","compatible","incompatible"]

# %%
df_zip['trial_bin'] = np.floor((df_zip.trial_num) / 12)

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="block",
                hue="compatibility",
                hue_order = compatibility_order,
                col="iterationName",
                kind="line",
                height=4.6,
                aspect=1)
# plt.title('rt by block')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="trial_num",
                hue="compatibility",
                hue_order = compatibility_order,
#                 col="trial_num",
                row= 'iterationName',
                kind="line",
                height=4.6,
                aspect=2)
# plt.ylim(800,1500)
plt.title('rt by trial_num')
plt.show()

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="trial_bin",
                hue="compatibility",
                hue_order = compatibility_order,
#                 col="trial_num",
                kind="line",
                height=4.6,
                aspect=2)
# plt.ylim(800,1500)
plt.title('rt by trial bin')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-437f66e47d06> in <module>
# ----> 1 g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
#       2                 y="rt",
#       3                 x="trial_bin",
#       4                 hue="compatibility",
#       5                 hue_order = compatibility_order,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1034
#    1035     # Draw the plot
# -> 1036     g.map_dataframe(func, **plot_kws)
#    1037
#    1038     # Label the axes
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     775
#     776             # Draw the plot
# --> 777             self._facet_plot(func, ax, args, kwargs)
#     778
#     779         # For axis labels, prefer to use positional args for backcompat
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1957             # setting for extensionarrays that store dicts. Need to decide
#    1958             # if it's worth supporting that.
# -> 1959             value = self._align_series(indexer, Series(value))
#    1960
#    1961         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094             # series, so need to broadcast (see GH5206)
#    2095             if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4577     )
#    4578     def reindex(self, index=None, **kwargs):
# -> 4579         return super().reindex(index=index, **kwargs)
#    4580
#    4581     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4807
#    4808         # perform the reindex on the axes
# -> 4809         return self._reindex_axes(
#    4810             axes, level, limit, tolerance, method, fill_value, copy
#    4811         ).__finalize__(self, method="reindex")
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4828
#    4829             axis = self._get_axis_number(a)
# -> 4830             obj = obj._reindex_with_indexers(
#    4831                 {axis: [new_index, indexer]},
#    4832                 fill_value=fill_value,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4872
#    4873             # TODO: speed up on homogeneous DataFrame objects
# -> 4874             new_data = new_data.reindex_indexer(
#    4875                 index,
#    4876                 indexer,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     664         # some axes don't allow reindexing with dups
#     665         if not allow_dups:
# --> 666             self.axes[axis]._validate_can_reindex(indexer)
#     667
#     668         if axis >= self.ndim:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="trial_bin",
                hue="compatibility",
                hue_order = compatibility_order,
                style="validity",
                kind="line",
                height=4.6,
                aspect=2)
# plt.ylim(800,1500)
plt.title('rt by trial bin')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-b67f79be5959> in <module>
# ----> 1 g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
#       2                 y="rt",
#       3                 x="trial_bin",
#       4                 hue="compatibility",
#       5                 hue_order = compatibility_order,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1034
#    1035     # Draw the plot
# -> 1036     g.map_dataframe(func, **plot_kws)
#    1037
#    1038     # Label the axes
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     775
#     776             # Draw the plot
# --> 777             self._facet_plot(func, ax, args, kwargs)
#     778
#     779         # For axis labels, prefer to use positional args for backcompat
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/opt/miniconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1957             # setting for extensionarrays that store dicts. Need to decide
#    1958             # if it's worth supporting that.
# -> 1959             value = self._align_series(indexer, Series(value))
#    1960
#    1961         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094             # series, so need to broadcast (see GH5206)
#    2095             if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4577     )
#    4578     def reindex(self, index=None, **kwargs):
# -> 4579         return super().reindex(index=index, **kwargs)
#    4580
#    4581     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4807
#    4808         # perform the reindex on the axes
# -> 4809         return self._reindex_axes(
#    4810             axes, level, limit, tolerance, method, fill_value, copy
#    4811         ).__finalize__(self, method="reindex")
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4828
#    4829             axis = self._get_axis_number(a)
# -> 4830             obj = obj._reindex_with_indexers(
#    4831                 {axis: [new_index, indexer]},
#    4832                 fill_value=fill_value,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4872
#    4873             # TODO: speed up on homogeneous DataFrame objects
# -> 4874             new_data = new_data.reindex_indexer(
#    4875                 index,
#    4876                 indexer,
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     664         # some axes don't allow reindexing with dups
#     665         if not allow_dups:
# --> 666             self.axes[axis]._validate_can_reindex(indexer)
#     667
#     668         if axis >= self.ndim:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="block",
                hue="compatibility",
                col="iterationName",
                kind="line",
                hue_order = compatibility_order,
                height=4.6,
                aspect=1)
# plt.ylim(0,1)
# plt.title('zipping accuracy by block and condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="trial_num",
                hue="compatibility",
                hue_order = compatibility_order,
#                 col="trial_num",
                kind="line",
                height=4.6,
                aspect=2)

plt.title('zipping accuracy by trial_num')
plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="trial_bin",
                hue="compatibility",
                hue_order = compatibility_order,
#                 col="trial_num",
                kind="line",
                height=4.6,
                aspect=2)

plt.title('zipping accuracy by trial bin')
plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.relplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="trial_bin",
                hue="compatibility",
                style="validity",
#                 col="trial_num",
                kind="line",
                height=4.6,
                aspect=2)

plt.title('zipping accuracy by trial bin')
plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
df_zip.phase
# Out:
# 0       post_zipping_trials
# 1       post_zipping_trials
# 2       post_zipping_trials
# 3       post_zipping_trials
# 4       post_zipping_trials
#                ...
# 1939    post_zipping_trials
# 1940    post_zipping_trials
# 1941    post_zipping_trials
# 1942    post_zipping_trials
# 1943    post_zipping_trials
# Name: phase, Length: 1944, dtype: object

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="compatibility",
                col="phase",
                row="iterationName",
                hue_order = compatibility_order,
                order = compatibility_order,
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="rt",
                x="compatibility",
                dodge=True,
                col="phase",
                hue_order = compatibility_order,
                order = compatibility_order,
                row="iterationName",
                kind="bar",
                height=4.6,
                aspect=0.8)
# plt.title('response time by condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="rt",
                hue="compatibility",
                dodge=False,
                x="block",
                hue_order=compatibility_order,
#                 row="validity",
#                 order = compatibility_order,
                col="iterationName",
                kind="point",
                height=4.6,
                aspect=1)
# plt.title('response time by condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct",
                hue="compatibility",
                dodge=False,
                x="block",
                hue_order=compatibility_order,
#                 order = compatibility_order,
                col="iterationName",
                kind="point",
                height=4.6,
                aspect=1)
# plt.title('response time by condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                hue="phase",
                x="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.title('accuracy by phase and condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                hue="phase",
                x="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.title('response time by phase and condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="block",
                hue="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.title('accuracy by block and condition')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="block",
                hue="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.title('response time by block and condition')
plt.show()

# %% [markdown]
# ### Validity

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT) & (df_zip.phase=="post_zipping_trials")],
                y="response_correct", 
                x="validity",
#                 col="trial_num",
                col="iterationName",
#                 col="phase",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT) & (df_zip.phase=="pre_zipping_trials")],
                y="response_correct", 
                x="compatibility",
                col="validity",
                row="iterationName",
                hue_order = compatibility_order,
                order = compatibility_order,
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT) & (df_zip.phase=="pre_zipping_trials")],
                y="rt", 
                x="compatibility",
                col="validity",
                row="iterationName",
                hue_order = compatibility_order,
                order = compatibility_order,
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
# plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT) & (df_zip.phase=="post_zipping_trials")],
                y="rt", 
                x="validity",
                col="iterationName",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
# plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="validity",
                col="part_type",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.ylim(0,1)
# plt.title('zipping accuracy by condition')
# plt.axhline(y=0.5, color='darkgrey', linestyle='--')
plt.show()

# %% [markdown]
# ## Wide vs Tall

# %%
g = sns.catplot(data=df_zip,
                y="response_correct", 
                x="part_type",
                palette="YlGnBu",
#                 hue="compatibility",
                col="phase",
                row="iterationName",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
# plt.title('response time by orientation')
plt.ylim((0.5,1))
plt.show()

# %%
g = sns.catplot(data=df_zip,
                y="rt", 
                x="part_type",
#                 hue="compatibility",
                palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.title('response time by orientation')
plt.show()

# %% [markdown]
# ## Item

# %%
composite_order = np.sort(df_zip.composite_id.unique())

# %%
import requests

def show(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    plt.figure(figsize=(1,2))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

def toCompositeURL(stimID):
    stimURL = "https://zipping-composites-png-rerender.s3.amazonaws.com/tower_4_block_unique_silhouette_composites_silhouette_" + stimID + ".png"
    return(stimURL)

_ = [(print(stimID), show(toCompositeURL(stimID))) for stimID in composite_order]
# Out:
# talls_101_114
# talls_102_122
# talls_111_127

# %%
g = sns.catplot(data=df_zip,
#                 col="composite_id",
                y="rt", 
                x="composite_id",
#                 hue="part_type",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip[df_zip.phase=='post_zipping_trials'],
                col="composite_id",
                y="response_correct", 
#                 hue="part_type",
                x="compatibility",
                order=compatibility_order,
                row = "iterationName",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip[df_zip.phase=='post_zipping_trials'],
                col="composite_id",
                y="rt", 
#                 hue="part_type",
                x="compatibility",
                order=compatibility_order,
                row = "iterationName",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
#                 col="composite_id",
                y="response_correct", 
                x="composite_id",
#                 hue="part_type",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
                col="composite_id",
                y="response_correct", 
#                 hue="part_type",
                x="compatibility",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %% [markdown]
# ### Item by wide and tall

# %%
g = sns.catplot(data=df_zip,
#                 col="composite_id",
                y="rt", 
                x="composite_id",
                hue="part_type",
                palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
                col="composite_id",
                y="rt", 
                hue="part_type",
                x="compatibility",
                palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
#                 col="composite_id",
                y="response_correct", 
                x="composite_id",
                hue="part_type",
                palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
                col="composite_id",
                y="response_correct", 
                hue="part_type",
                x="compatibility",
                palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
df_zip_item_compatibility_mean = df_zip.groupby(['gameID','composite_id','compatibility']).mean().reset_index()\
                                    .query('compatibility in ["compatible","incompatible"]')

# %%
ppt_item_compatibility_diffs = df_zip_item_compatibility_mean.groupby(['gameID','composite_id'])\
    [['response_correct','rt','compatibility']]

# %%
ppt_item_compatibility_diffs_comp_incomp = ppt_item_compatibility_diffs.apply(compatibility_diff).reset_index()

# %%
sns.swarmplot(data=ppt_item_compatibility_diffs_comp_incomp,
            y='diff_rt',
            x='composite_id',
            order=composite_order)
# Out:
# <AxesSubplot:xlabel='composite_id', ylabel='diff_rt'>

# %%
sns.swarmplot(data=ppt_item_compatibility_diffs_comp_incomp,
            y='diff_response_correct',
            x='composite_id',
            order=composite_order)
# Out:
# <AxesSubplot:xlabel='composite_id', ylabel='diff_response_correct'>

# %%
_ = [(print(stimID), show(toCompositeURL(stimID))) for stimID in composite_order]
# Out:
# talls_101_114
# talls_102_122
# talls_111_127

# %% [markdown]
# ## Block and condition

# %% [markdown]
# #### RT

# %%
sns.lineplot(data = df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="block",
                hue="compatibility",
            )
plt.title('response time by block and condition')
# Out:
# Text(0.5, 1.0, 'response time by block and condition')

# %%
sns.lineplot(data = df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="block",
                style="validity",
                hue="compatibility",
            )
plt.title('response time by block and condition')
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# The expectation was that rt would drop for compatible and (maybe) rise for incompatible.
# But RT is higher for all conditions after the building task.
# And even after practice they don't get as fast as they used to be.
# What's going on?
#
# What's the simplest explanation of this?
# People get tired? But then they would continue to get worse.
#
# People are taking longer to parse the objects?
# But if so, they're doing it indiscriminantly- there is no difference between novel and built.

# %% [markdown]
# #### accuracy

# %%
sns.lineplot(data = df_zip,
                y="response_correct", 
                x="block",
                hue="compatibility",
            )
plt.title('accuracy time by block and condition')
# Out:
# Text(0.5, 1.0, 'accuracy time by block and condition')

# %% [markdown]
# But they're more accurate.

# %% [markdown]
# ### Stimuli
#
# Does the same pattern hold across different stimulus 'rotations'?
#
# There are three stimuli that we rotate into different positions.
# Each of the three stims can be novel. And the other two stims can have wide parts built or tall parts built.

# %%
# response time by block and condition, separated by rotation 

f = sns.relplot(data = df_zip[(~df_zip.flagRT)],
                col = 'rotation_name',
                y="rt", 
                x="block",
                hue="compatibility",
                kind='line')

# %%
sns.lineplot(data = df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="block",
                hue="compatibility",
            )

plt.title('accuracy by block and condition')
# Out:
# Text(0.5, 1.0, 'accuracy by block and condition')

# %%
sns.relplot(data = df_zip[(~df_zip.flagRT)],
                col = 'rotation_name',
                y="response_correct", 
                x="block",
                hue="compatibility",
                kind='line')

plt.title('accuracy by block and condition, separated by rotation')
# Out:
# Text(0.5, 1.0, 'accuracy by block and condition, separated by rotation')

# %%
# We want to look at the interaction between phase, compatibility 

g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="rt", 
                x="phase",
                hue="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.show()

# %%
# We want to look at the interaction between phase, compatibility 

g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="phase",
                hue="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.show()

# %% [markdown]
# ## zipping trials- participant level performance

# %%
plt.figure(figsize=(12,9))

sns.pointplot(data = df_zip,
              y = 'response_correct',
              x = 'compatibility',
              hue = 'gameID')

plt.legend([],[], frameon=False)

# %%
df_zip['log_rt'] = np.log(df_zip.rt)

# %%
plt.figure(figsize=(12,9))

sns.pointplot(data = df_zip,
              y = 'log_rt',
              x = 'compatibility',
              hue = 'gameID')

plt.legend([],[], frameon=False)

# %% [markdown]
# Variation in participant performance

# %%
df_zip_ppt_mean = df_zip.groupby(['gameID']).mean().reset_index()\
                    .merge(df_zip[['gameID','rotation_name','iterationName']].groupby('gameID').last().reset_index(), 
                                                                        how='left',
                                                                        on='gameID')

# %%
sns.displot(df_zip_ppt_mean[df_zip_ppt_mean.iterationName=="pre_post_run_0"], 
            x='rt', 
            col="iterationName",
            kind='hist',
            stat='proportion'
           )

# %%
sns.displot(df_zip_ppt_mean[df_zip_ppt_mean.iterationName=="pre_post_run_0"], 
            x='response_correct', 
            col="iterationName",
            kind='hist',
            stat='proportion'
           )
plt.xlim((0,1))
# Out:
# (0.0, 1.0)

# %%
sns.displot(df_zip_ppt_mean[df_zip_ppt_mean.iterationName=="post_run_0"], 
            x='rt', 
            col="iterationName",
            kind='hist',
            stat='proportion'
           )

# %%
sns.displot(df_zip_ppt_mean[df_zip_ppt_mean.iterationName=="post_run_0"], 
            x='response_correct', 
            col="iterationName",
            kind='hist',
            stat='proportion'
           )
plt.xlim((0,1))
# Out:
# (0.0, 1.0)

# %%
# anything that effects ppt level performance?

# %%
rotations = df_meta[['rotation', 'rotation_name']].groupby('rotation_name').first()
rotations = rotations.to_dict()

# %%
import requests

# %%
def show_stim(url, ax):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
#     plt.figure(figsize=(2,1))
    ax.imshow(img)
    ax.axis('off')
    
def display_rotation(rotation_name, 
                     url_stem = 'https://tower-4-block-unique-silhouettes-composite-silhouette-png.s3.amazonaws.com/tower_4_block_unique_silhouette_composites_silhouette_{}.png'):
    print(rotation_name)
    print('build_wide      build_tall      novel')
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
    show_stim(url_stem.format(rotations['rotation'][rotation_name]['build_wide']), ax1)
    show_stim(url_stem.format(rotations['rotation'][rotation_name]['build_tall']), ax2)
    show_stim(url_stem.format(rotations['rotation'][rotation_name]['novel']), ax3)


def show_part(part_id,
              verbose = False,
              url_stem = "https://lax-tower-4-block-unique-silhouettes-png.s3.amazonaws.com/tower_4_block_unique_silhouette_{}.png"):
    
    if verbose:
        print(part_id)
    response = requests.get(url_stem.format(part_id.split('_')[1]))
    img = Image.open(BytesIO(response.content))
    plt.figure(figsize=(3,2))
    plt.imshow(img)
    plt.axis('off')
    
def show_part_subplot(part_id,
                      ax,
              url_stem = "https://lax-tower-4-block-unique-silhouettes-png.s3.amazonaws.com/tower_4_block_unique_silhouette_{}.png"):
    
    response = requests.get(url_stem.format(part_id.split('_')[1]))
    img = Image.open(BytesIO(response.content))
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(part_id)

# %%
rotation_order = np.sort(df_zip_ppt_mean.rotation_name.unique())

# %%
sns.barplot(data=df_zip_ppt_mean,
            y='rt',
            x='rotation_name',
            order = rotation_order)
# Out:
# <AxesSubplot:xlabel='rotation_name', ylabel='rt'>

# %%
sns.swarmplot(data=df_zip_ppt_mean,
            y='rt',
            x='rotation_name',
            order = rotation_order)
# Out:
# <AxesSubplot:xlabel='rotation_name', ylabel='rt'>

# %%
sns.barplot(data=df_zip_ppt_mean,
            y='response_correct',
            x='rotation_name',
            order = rotation_order)
# Out:
# <AxesSubplot:xlabel='rotation_name', ylabel='response_correct'>

# %%
sns.swarmplot(data=df_zip_ppt_mean,
            y='response_correct',
            x='rotation_name',
            order = rotation_order)
# Out:
# <AxesSubplot:xlabel='rotation_name', ylabel='response_correct'>

# %%
g = sns.catplot(data=df_zip,
                col="rotation_name",
                col_order=rotation_order,
                y="rt", 
#                 hue="part_type",
                x="compatibility",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
g = sns.catplot(data=df_zip,
                col="rotation_name",
                col_order=rotation_order,
                y="response_correct", 
#                 hue="part_type",
                x="compatibility",
#                 palette="YlGnBu",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=1)
plt.show()

# %%
display_rotation(rotation_order[0])
# Out:
# p_1
# build_wide      build_tall      novel

# %%
display_rotation(rotation_order[1])
# Out:
# p_2
# build_wide      build_tall      novel

# %%
display_rotation(rotation_order[2])
# Out:
# q_1
# build_wide      build_tall      novel

# %%
display_rotation(rotation_order[3])
# Out:
# q_2
# build_wide      build_tall      novel

# %%
display_rotation(rotation_order[4])
# Out:
# r_1
# build_wide      build_tall      novel

# %%
display_rotation(rotation_order[5])
# Out:
# r_2
# build_wide      build_tall      novel

# %%
# looking for speed accuracy trade-off

sns.scatterplot(data = df_zip_ppt_mean,
                x = 'rt',
                y = 'response_correct')
# Out:
# <AxesSubplot:xlabel='rt', ylabel='response_correct'>

# %% [markdown]
# # Within PPT differences
#
# Between compatible and incompatible

# %%
df_zip_compatibility_mean = df_zip.groupby(['gameID','compatibility']).mean().reset_index()

# %%
ppt_compatibility_diffs = df_zip_compatibility_mean.groupby(['gameID'])[['response_correct','rt','compatibility']]

# %%
ppt_compatibility_diffs_comp_incomp = ppt_compatibility_diffs.apply(compatibility_diff)

# %%
ppt_compatibility_diffs_nov_comp = \
    ppt_compatibility_diffs.apply(compatibility_diff, compatibilities=['novel','incompatible'])

# %%
sns.swarmplot(data = ppt_compatibility_diffs_comp_incomp,
            y = 'diff_response_correct')

plt.title('difference between compatible and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible')

# %%
sns.swarmplot(data = ppt_compatibility_diffs_comp_incomp,
            y = 'diff_rt')

plt.title('difference between compatible and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible')

# %%
sns.displot(data = ppt_compatibility_diffs_comp_incomp,
            x = 'diff_response_correct')

plt.title('difference between compatible and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible')

# %%
sns.displot(data = ppt_compatibility_diffs_comp_incomp,
            x = 'diff_rt')

plt.title('difference between compatible and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible')

# %%
sns.displot(data = ppt_compatibility_diffs_nov_comp,
            x = 'diff_response_correct',
            bins=10)

plt.title('difference between novel and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible')

# %%
sns.displot(data = ppt_compatibility_diffs_nov_comp,
            x = 'diff_rt',
            bins=10)

plt.title('difference between novel and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible')

# %%
sns.swarmplot(data = ppt_compatibility_diffs_nov_comp,
            y = 'diff_response_correct')

plt.title('difference between novel and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible')

# %%
sns.swarmplot(data = ppt_compatibility_diffs_nov_comp,
            y = 'diff_rt')

plt.title('difference between novel and incompatible')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible')

# %% [markdown]
# ## Differences between conditions by mean task performance

# %%
df_zip_diffs_nov_comp = ppt_compatibility_diffs_nov_comp.merge(df_zip_ppt_mean, on='gameID')
df_zip_diffs_comp_incomp = ppt_compatibility_diffs_comp_incomp.merge(df_zip_ppt_mean, on='gameID')

# %%
df_zip_diffs_comp_incomp
# Out:
#                                        gameID  diff_response_correct  \
# 0   0581-6a290675-ac2d-4446-a181-3d3e545c534e              -0.041667
# 1   1199-27a29656-1dbe-4aeb-9305-8dbd12e55839              -0.166667
# 2   1711-d5c126e7-318a-4ebd-bccf-e865f5c0e2e1              -0.041667
# 3   1945-8f8714ae-b89b-4ca0-b013-3373fc5763da               0.208333
# 4   2002-0d32a6aa-c1d1-4585-aee2-b0e79561065d               0.083333
# 5   2180-6e340123-d0e2-47e1-a832-4a0c061db44b               0.041667
# 6   2251-16ae277d-65bc-4fcc-85d2-5976fc60fdd6              -0.250000
# 7   2497-d16fe438-1b10-4726-b497-72abb758767b              -0.166667
# 8   2712-3ef02430-77ed-4234-9278-5b5afb277889               0.041667
# 9   2722-e9ac1150-6375-4d66-be29-19cec364601f               0.166667
# 10  3242-3ef510a0-a88a-4469-8644-c313768b8e12              -0.041667
# 11  3824-1645087e-8b8d-4f26-82a3-1b2b04bfca3b              -0.125000
# 12  3944-608b2a6c-e1bc-4a9e-b62d-40311ec10668              -0.041667
# 13  4584-bbb653af-a114-4cd0-afc1-62cda8a3b118              -0.083333
# 14  4628-3e0312f5-9804-479a-b877-7cfd37b43dc5              -0.166667
# 15  4773-f620c738-7010-4b5d-998b-76907f7dd360               0.166667
# 16  4822-ca43fbc6-d987-42ea-8d07-b10734a15745              -0.041667
# 17  5333-28aa563c-5430-4783-b34e-a6df0d7b5c0a               0.208333
# 18  5388-1ed25a27-e3ca-46fb-a3bc-35dc2b3fbea3               0.125000
# 19  5766-610e95c0-a258-4df0-957d-1740d229a606               0.041667
# 20  6442-e435966a-6e09-47ab-a88f-76d59919ade7              -0.041667
# 21  6940-1c19ec14-112f-428a-b05c-9c7dc11e4004               0.000000
# 22  7607-de5babf9-9205-4178-a5ed-8f4671bd7c04              -0.125000
# 23  8208-2927441a-c7dd-4370-a33f-ce59e7cac595               0.041667
# 24  8323-1f14a318-9b9e-4ca8-b136-9ee8d411958e              -0.041667
# 25  9165-a89fbce3-5cb1-4b1e-8ef8-b546d032ad92              -0.083333
# 26  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec               0.208333
#
#        diff_rt        index  trial_start_time  trial_finish_time           rt  \
# 0   128.412500  2329.888889      1.660176e+12       1.660176e+12  1311.555556
# 1   138.920833  2197.236111      1.660176e+12       1.660176e+12  1553.652778
# 2    25.312500   917.541667      1.658775e+12       1.658775e+12   962.265278
# 3    10.770833  2621.375000      1.660177e+12       1.660177e+12  1006.277778
# 4    18.629167  2125.875000      1.660176e+12       1.660176e+12  1075.838889
# 5    40.770833  1379.930556      1.660174e+12       1.660174e+12  1130.972222
# 6   -71.041667   821.180556      1.658775e+12       1.658775e+12   957.104167
# 7   -73.345833  1067.625000      1.658775e+12       1.658775e+12   861.451389
# 8    52.695833  1023.736111      1.658775e+12       1.658775e+12  1372.100000
# 9    55.733333  1939.930556      1.660176e+12       1.660176e+12  1086.694444
# 10  -11.720833  2066.236111      1.660176e+12       1.660176e+12  1247.208333
# 11 -109.312500   950.791667      1.658775e+12       1.658775e+12  1416.456944
# 12    0.895833  1269.888889      1.660174e+12       1.660174e+12  1317.193056
# 13 -144.079167  2177.972222      1.660176e+12       1.660176e+12  1628.733333
# 14   14.716667  1999.166667      1.660176e+12       1.660176e+12  1664.191667
# 15 -183.920833  1728.388889      1.660175e+12       1.660175e+12   988.202778
# 16  -15.162500   647.500000      1.658541e+12       1.658541e+12  1446.990278
# 17   -2.233333  2331.416667      1.660176e+12       1.660176e+12  1791.444444
# 18 -645.591667  1392.916667      1.660174e+12       1.660174e+12  2313.429167
# 19 -184.725917  1746.458333      1.660175e+12       1.660175e+12   918.305403
# 20 -137.687500  2356.666667      1.660176e+12       1.660176e+12  1158.770833
# 21   23.329167  2699.500000      1.660190e+12       1.660190e+12   852.715278
# 22  -53.045833  1572.083333      1.660175e+12       1.660175e+12  1335.891667
# 23   -2.033333   723.500000      1.658542e+12       1.658542e+12  1140.027778
# 24  185.975000  1821.555556      1.660175e+12       1.660175e+12  1493.933333
# 25   52.054167  1246.944444      1.660174e+12       1.660174e+12   738.027778
# 26   31.758333  1399.416667      1.660174e+12       1.660174e+12  1019.340278
#
#     response_correct  practice  composite_duration  gap_duration  \
# 0           0.638889       0.0               600.0         400.0
# 1           0.708333       0.0               600.0         400.0
# 2           0.750000       0.0               600.0         400.0
# 3           0.722222       0.0               600.0         400.0
# 4           0.777778       0.0               600.0         400.0
# 5           0.625000       0.0               600.0         400.0
# 6           0.708333       0.0               600.0         400.0
# 7           0.666667       0.0               600.0         400.0
# 8           0.722222       0.0               600.0         400.0
# 9           0.666667       0.0               600.0         400.0
# 10          0.722222       0.0               600.0         400.0
# 11          0.736111       0.0               600.0         400.0
# 12          0.736111       0.0               600.0         400.0
# 13          0.791667       0.0               600.0         400.0
# 14          0.708333       0.0               600.0         400.0
# 15          0.861111       0.0               600.0         400.0
# 16          0.555556       0.0               600.0         400.0
# 17          0.875000       0.0               600.0         400.0
# 18          0.708333       0.0               600.0         400.0
# 19          0.555556       0.0               600.0         400.0
# 20          0.513889       0.0               600.0         400.0
# 21          0.569444       0.0               600.0         400.0
# 22          0.722222       0.0               600.0         400.0
# 23          0.777778       0.0               600.0         400.0
# 24          0.722222       0.0               600.0         400.0
# 25          0.638889       0.0               600.0         400.0
# 26          0.750000       0.0               600.0         400.0
#
#     chunk_duration  stimVersionInd  key_presses  trial_index  time_elapsed  \
# 0           1000.0             1.0     0.000000         64.0  7.195063e+05
# 1           1000.0             1.0     0.000000         64.0  1.012029e+06
# 2           1000.0             1.0     0.000000         64.0  9.705923e+05
# 3           1000.0             1.0     0.000000         64.0  8.877524e+05
# 4           1000.0             1.0     0.000000         64.0  2.601491e+06
# 5           1000.0             1.0     0.000000         64.0  9.811090e+05
# 6           1000.0             1.0     0.000000         64.0  7.375185e+05
# 7           1000.0             1.0     0.000000         64.0  1.256525e+06
# 8           1000.0             1.0     0.000000         64.0  1.148303e+06
# 9           1000.0             1.0     0.000000         64.0  7.379469e+05
# 10          1000.0             1.0     0.000000         64.0  7.750193e+05
# 11          1000.0             1.0     0.000000         64.0  9.304070e+05
# 12          1000.0             1.0     0.000000         64.0  7.386772e+05
# 13          1000.0             1.0     0.000000         64.0  9.318737e+05
# 14          1000.0             1.0     0.000000         64.0  8.063734e+05
# 15          1000.0             1.0     0.000000         64.0  8.629221e+05
# 16          1000.0             1.0     0.083333         64.0  8.941298e+05
# 17          1000.0             1.0     0.000000         64.0  1.516019e+06
# 18          1000.0             1.0     0.000000         64.0  8.910074e+05
# 19          1000.0             1.0     0.138889         64.0  6.752785e+05
# 20          1000.0             1.0     0.013889         64.0  1.371658e+06
# 21          1000.0             1.0     0.166667         64.0  1.554205e+07
# 22          1000.0             1.0     0.013889         64.0  1.651313e+06
# 23          1000.0             1.0     0.000000         64.0  6.717291e+05
# 24          1000.0             1.0     0.000000         64.0  7.358230e+05
# 25          1000.0             1.0     0.000000         64.0  6.357981e+05
# 26          1000.0             1.0     0.000000         64.0  9.980241e+05
#
#     trial_num    flagRT  recalculated_response_correct rotation_name
# 0        35.5  0.000000                       0.638889           q_2
# 1        35.5  0.000000                       0.708333           r_1
# 2        35.5  0.000000                       0.750000           r_2
# 3        35.5  0.000000                       0.722222           p_1
# 4        35.5  0.000000                       0.777778           q_2
# 5        35.5  0.000000                       0.625000           p_1
# 6        35.5  0.000000                       0.708333           q_1
# 7        35.5  0.000000                       0.666667           p_2
# 8        35.5  0.000000                       0.722222           q_2
# 9        35.5  0.000000                       0.666667           q_1
# 10       35.5  0.000000                       0.722222           q_1
# 11       35.5  0.000000                       0.736111           r_1
# 12       35.5  0.000000                       0.736111           q_1
# 13       35.5  0.013889                       0.791667           p_2
# 14       35.5  0.000000                       0.708333           q_2
# 15       35.5  0.000000                       0.861111           r_1
# 16       35.5  0.013889                       0.555556           q_1
# 17       35.5  0.000000                       0.875000           r_1
# 18       35.5  0.041667                       0.708333           r_2
# 19       35.5  0.000000                       0.555556           q_2
# 20       35.5  0.000000                       0.513889           p_2
# 21       35.5  0.000000                       0.569444           p_1
# 22       35.5  0.000000                       0.722222           r_1
# 23       35.5  0.000000                       0.777778           q_2
# 24       35.5  0.000000                       0.722222           r_2
# 25       35.5  0.000000                       0.638889           p_2
# 26       35.5  0.013889                       0.750000           p_2

# %% [markdown]
# ### Novel to incompatible

# %%
sns.scatterplot(data = df_zip_diffs_nov_comp,
                x = 'rt',
                y = 'diff_rt')

plt.title('difference between novel and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_nov_comp,
                x = 'response_correct',
                y = 'diff_rt')

plt.title('difference between novel and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_nov_comp,
                x = 'rt',
                y = 'diff_response_correct')

plt.title('difference between novel and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_nov_comp,
                x = 'response_correct',
                y = 'diff_response_correct')

plt.title('difference between novel and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between novel and incompatible by average task performance')

# %% [markdown]
# ### compatible to incompatible

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'rt',
                y = 'diff_rt')

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'response_correct',
                y = 'diff_rt')

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'rt',
                y = 'diff_response_correct')

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'response_correct',
                y = 'diff_response_correct')

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %% [markdown]
# ### Differences in conditions by rotation

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'rotation_name',
                y = 'diff_response_correct',
                hue = 'rotation_name',
                hue_order = rotation_order,
                legend=False)

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %%
sns.scatterplot(data = df_zip_diffs_comp_incomp,
                x = 'rotation_name',
                y = 'diff_rt',
                hue = 'rotation_name',
                hue_order = rotation_order,
                legend=False)

plt.title('difference between compatible and incompatible by average task performance')
# Out:
# Text(0.5, 1.0, 'difference between compatible and incompatible by average task performance')

# %% [markdown]
# ### Part type

# %%
df_zip_ppt_mean      x
# Out:
#                                        gameID        index  trial_start_time  \
# 0   0581-6a290675-ac2d-4446-a181-3d3e545c534e  2329.888889      1.660176e+12
# 1   1199-27a29656-1dbe-4aeb-9305-8dbd12e55839  2197.236111      1.660176e+12
# 2   1711-d5c126e7-318a-4ebd-bccf-e865f5c0e2e1   917.541667      1.658775e+12
# 3   1945-8f8714ae-b89b-4ca0-b013-3373fc5763da  2621.375000      1.660177e+12
# 4   2002-0d32a6aa-c1d1-4585-aee2-b0e79561065d  2125.875000      1.660176e+12
# 5   2180-6e340123-d0e2-47e1-a832-4a0c061db44b  1379.930556      1.660174e+12
# 6   2251-16ae277d-65bc-4fcc-85d2-5976fc60fdd6   821.180556      1.658775e+12
# 7   2497-d16fe438-1b10-4726-b497-72abb758767b  1067.625000      1.658775e+12
# 8   2712-3ef02430-77ed-4234-9278-5b5afb277889  1023.736111      1.658775e+12
# 9   2722-e9ac1150-6375-4d66-be29-19cec364601f  1939.930556      1.660176e+12
# 10  3242-3ef510a0-a88a-4469-8644-c313768b8e12  2066.236111      1.660176e+12
# 11  3824-1645087e-8b8d-4f26-82a3-1b2b04bfca3b   950.791667      1.658775e+12
# 12  3944-608b2a6c-e1bc-4a9e-b62d-40311ec10668  1269.888889      1.660174e+12
# 13  4584-bbb653af-a114-4cd0-afc1-62cda8a3b118  2177.972222      1.660176e+12
# 14  4628-3e0312f5-9804-479a-b877-7cfd37b43dc5  1999.166667      1.660176e+12
# 15  4773-f620c738-7010-4b5d-998b-76907f7dd360  1728.388889      1.660175e+12
# 16  4822-ca43fbc6-d987-42ea-8d07-b10734a15745   647.500000      1.658541e+12
# 17  5333-28aa563c-5430-4783-b34e-a6df0d7b5c0a  2331.416667      1.660176e+12
# 18  5388-1ed25a27-e3ca-46fb-a3bc-35dc2b3fbea3  1392.916667      1.660174e+12
# 19  5766-610e95c0-a258-4df0-957d-1740d229a606  1746.458333      1.660175e+12
# 20  6442-e435966a-6e09-47ab-a88f-76d59919ade7  2356.666667      1.660176e+12
# 21  6940-1c19ec14-112f-428a-b05c-9c7dc11e4004  2699.500000      1.660190e+12
# 22  7607-de5babf9-9205-4178-a5ed-8f4671bd7c04  1572.083333      1.660175e+12
# 23  8208-2927441a-c7dd-4370-a33f-ce59e7cac595   723.500000      1.658542e+12
# 24  8323-1f14a318-9b9e-4ca8-b136-9ee8d411958e  1821.555556      1.660175e+12
# 25  9165-a89fbce3-5cb1-4b1e-8ef8-b546d032ad92  1246.944444      1.660174e+12
# 26  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec  1399.416667      1.660174e+12
#
#     trial_finish_time           rt  response_correct  practice  \
# 0        1.660176e+12  1311.555556          0.638889       0.0
# 1        1.660176e+12  1553.652778          0.708333       0.0
# 2        1.658775e+12   962.265278          0.750000       0.0
# 3        1.660177e+12  1006.277778          0.722222       0.0
# 4        1.660176e+12  1075.838889          0.777778       0.0
# 5        1.660174e+12  1130.972222          0.625000       0.0
# 6        1.658775e+12   957.104167          0.708333       0.0
# 7        1.658775e+12   861.451389          0.666667       0.0
# 8        1.658775e+12  1372.100000          0.722222       0.0
# 9        1.660176e+12  1086.694444          0.666667       0.0
# 10       1.660176e+12  1247.208333          0.722222       0.0
# 11       1.658775e+12  1416.456944          0.736111       0.0
# 12       1.660174e+12  1317.193056          0.736111       0.0
# 13       1.660176e+12  1628.733333          0.791667       0.0
# 14       1.660176e+12  1664.191667          0.708333       0.0
# 15       1.660175e+12   988.202778          0.861111       0.0
# 16       1.658541e+12  1446.990278          0.555556       0.0
# 17       1.660176e+12  1791.444444          0.875000       0.0
# 18       1.660174e+12  2313.429167          0.708333       0.0
# 19       1.660175e+12   918.305403          0.555556       0.0
# 20       1.660176e+12  1158.770833          0.513889       0.0
# 21       1.660190e+12   852.715278          0.569444       0.0
# 22       1.660175e+12  1335.891667          0.722222       0.0
# 23       1.658542e+12  1140.027778          0.777778       0.0
# 24       1.660175e+12  1493.933333          0.722222       0.0
# 25       1.660174e+12   738.027778          0.638889       0.0
# 26       1.660174e+12  1019.340278          0.750000       0.0
#
#     composite_duration  gap_duration  chunk_duration  stimVersionInd  \
# 0                600.0         400.0          1000.0             1.0
# 1                600.0         400.0          1000.0             1.0
# 2                600.0         400.0          1000.0             1.0
# 3                600.0         400.0          1000.0             1.0
# 4                600.0         400.0          1000.0             1.0
# 5                600.0         400.0          1000.0             1.0
# 6                600.0         400.0          1000.0             1.0
# 7                600.0         400.0          1000.0             1.0
# 8                600.0         400.0          1000.0             1.0
# 9                600.0         400.0          1000.0             1.0
# 10               600.0         400.0          1000.0             1.0
# 11               600.0         400.0          1000.0             1.0
# 12               600.0         400.0          1000.0             1.0
# 13               600.0         400.0          1000.0             1.0
# 14               600.0         400.0          1000.0             1.0
# 15               600.0         400.0          1000.0             1.0
# 16               600.0         400.0          1000.0             1.0
# 17               600.0         400.0          1000.0             1.0
# 18               600.0         400.0          1000.0             1.0
# 19               600.0         400.0          1000.0             1.0
# 20               600.0         400.0          1000.0             1.0
# 21               600.0         400.0          1000.0             1.0
# 22               600.0         400.0          1000.0             1.0
# 23               600.0         400.0          1000.0             1.0
# 24               600.0         400.0          1000.0             1.0
# 25               600.0         400.0          1000.0             1.0
# 26               600.0         400.0          1000.0             1.0
#
#     key_presses  trial_index  time_elapsed  trial_num    flagRT  \
# 0      0.000000         64.0  7.195063e+05       35.5  0.000000
# 1      0.000000         64.0  1.012029e+06       35.5  0.000000
# 2      0.000000         64.0  9.705923e+05       35.5  0.000000
# 3      0.000000         64.0  8.877524e+05       35.5  0.000000
# 4      0.000000         64.0  2.601491e+06       35.5  0.000000
# 5      0.000000         64.0  9.811090e+05       35.5  0.000000
# 6      0.000000         64.0  7.375185e+05       35.5  0.000000
# 7      0.000000         64.0  1.256525e+06       35.5  0.000000
# 8      0.000000         64.0  1.148303e+06       35.5  0.000000
# 9      0.000000         64.0  7.379469e+05       35.5  0.000000
# 10     0.000000         64.0  7.750193e+05       35.5  0.000000
# 11     0.000000         64.0  9.304070e+05       35.5  0.000000
# 12     0.000000         64.0  7.386772e+05       35.5  0.000000
# 13     0.000000         64.0  9.318737e+05       35.5  0.013889
# 14     0.000000         64.0  8.063734e+05       35.5  0.000000
# 15     0.000000         64.0  8.629221e+05       35.5  0.000000
# 16     0.083333         64.0  8.941298e+05       35.5  0.013889
# 17     0.000000         64.0  1.516019e+06       35.5  0.000000
# 18     0.000000         64.0  8.910074e+05       35.5  0.041667
# 19     0.138889         64.0  6.752785e+05       35.5  0.000000
# 20     0.013889         64.0  1.371658e+06       35.5  0.000000
# 21     0.166667         64.0  1.554205e+07       35.5  0.000000
# 22     0.013889         64.0  1.651313e+06       35.5  0.000000
# 23     0.000000         64.0  6.717291e+05       35.5  0.000000
# 24     0.000000         64.0  7.358230e+05       35.5  0.000000
# 25     0.000000         64.0  6.357981e+05       35.5  0.000000
# 26     0.000000         64.0  9.980241e+05       35.5  0.013889
#
#     recalculated_response_correct rotation_name
# 0                        0.638889           q_2
# 1                        0.708333           r_1
# 2                        0.750000           r_2
# 3                        0.722222           p_1
# 4                        0.777778           q_2
# 5                        0.625000           p_1
# 6                        0.708333           q_1
# 7                        0.666667           p_2
# 8                        0.722222           q_2
# 9                        0.666667           q_1
# 10                       0.722222           q_1
# 11                       0.736111           r_1
# 12                       0.736111           q_1
# 13                       0.791667           p_2
# 14                       0.708333           q_2
# 15                       0.861111           r_1
# 16                       0.555556           q_1
# 17                       0.875000           r_1
# 18                       0.708333           r_2
# 19                       0.555556           q_2
# 20                       0.513889           p_2
# 21                       0.569444           p_1
# 22                       0.722222           r_1
# 23                       0.777778           q_2
# 24                       0.722222           r_2
# 25                       0.638889           p_2
# 26                       0.750000           p_2

# %%
g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="part_type",
#                 hue="compatibility",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.show()

# %% [markdown]
# ### Stimulus

# %%
# Is one of the stims easier across the board?

g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="composite_id",
#                 hue="part_type",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.show()

# %%
# Are any of the stims easier in one direction?

g = sns.catplot(data=df_zip[(~df_zip.flagRT)],
                y="response_correct", 
                x="composite_id",
                hue="part_type",
                dodge=True,
                kind="bar",
                height=4.6,
                aspect=0.8)
plt.show()

# %% [markdown]
# ## d'

# %%
from scipy.stats import norm

Z = norm.ppf

# %%
def d_primes(df):
    
    # find hit rate H, proportion of yes trials with response M
    #df_zip[(df_zip.response=='m') & (df_zip.validity == 'valid')]
    yes_trials = df[df.validity=='valid']
    
    H = len(yes_trials[yes_trials.response==df[df.validity=='valid']['expected_response']])/ len(yes_trials)
    
    # replace hit rates to avoid inf d-prime
#     half_hit = 0.5 / len(yes_trials)
    if H == 1: 
#         H = 1 - half_hit
        H = 0.9999
    if H == 0: 
#         H = half_hit
        H = 0.0001
    

    # find false alarm rate F, proportion of no trials with response M
    no_trials = df[df.validity=='invalid']
    
    F = len(no_trials[no_trials.response!=df[df.validity=='invalid']['expected_response']])/ len(no_trials)
    
    # replace hit rates to avoid inf d-prime
#     half_fa = 0.5 / len(no_trials)
    if F == 1: 
#         F = 1 - half_fa
        F = 0.9999
    if F == 0: 
#         F = half_fa
        F = 0.0001
    
    
    d_prime = Z(H) - Z(F)
    
    return d_prime

# %%
d_blocks = df_zip[~df_zip.flagRT].groupby(['gameID','block']).apply(d_primes).reset_index()
d_blocks = d_blocks.rename(columns = {0: 'd_prime'})

# %%
sns.barplot(data = d_blocks,
            y = 'd_prime',
            x = 'block',
            order=block_order)
# Out:
# <AxesSubplot:xlabel='block', ylabel='d_prime'>

# %%
d_phase = df_zip[~df_zip.flagRT].groupby(['gameID','phase']).apply(d_primes).reset_index()
d_phase = d_phase.rename(columns = {0: 'd_prime'})

# %%
sns.barplot(data = d_phase,
            y = 'd_prime',
            x = 'phase',
            order = phase_order)
# Out:
# <AxesSubplot:xlabel='phase', ylabel='d_prime'>

# %%
d_phase_compatibility = df_zip[~df_zip.flagRT].groupby(['gameID','phase','compatibility']).apply(d_primes).reset_index()
d_phase_compatibility = d_phase_compatibility.rename(columns = {0: 'd_prime'})

# %%
sns.barplot(data = d_phase_compatibility,
            y = 'd_prime',
            x = 'phase',
            hue = 'compatibility',
            order = phase_order)
# Out:
# <AxesSubplot:xlabel='phase', ylabel='d_prime'>

# %%
sns.barplot(data = d_phase_compatibility,
            y = 'd_prime',
            hue = 'phase',
            x = 'compatibility',
            hue_order = phase_order)
# Out:
# <AxesSubplot:xlabel='compatibility', ylabel='d_prime'>

# %%
d_block_compatibility = df_zip[~df_zip.flagRT].groupby(['gameID','block','compatibility']).apply(d_primes).reset_index()
d_block_compatibility = d_block_compatibility.rename(columns = {0: 'd_prime'})

# %%
sns.barplot(data = d_block_compatibility,
            y = 'd_prime',
            hue = 'block',
            x = 'compatibility',
            hue_order = block_order)
plt.legend(bbox_to_anchor=(1,1))

# %%
sns.barplot(data = d_block_compatibility,
            y = 'd_prime',
            x = 'block',
            hue = 'compatibility',
            order = block_order)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ## Building Trials

# %%
df_build['trial_duration'] = df_build.timeAbsolute - df_build.trial_start_time
df_build['trial_duration_min'] =  df_build['trial_duration'] / (60 * 1000)

# %% [markdown]
# ### whole trials

# %%
ppts_left = list(df_zip.gameID.unique())

# %%
df_build = df_build[df_build.gameID.isin(ppts_left)]

# %%
df_ppt_info = df_zip[['gameID', 'rotation_name']].groupby('gameID').first()

# %%
df_build_means = df_build.groupby('gameID').mean().reset_index().merge(df_ppt_info, how='left', on='gameID')
df_build_phase_means = df_build.groupby(['gameID','rep']).mean().reset_index().merge(df_ppt_info, how='left', on='gameID')
df_build_part_means = df_build.groupby(['gameID','chunk_id']).mean().reset_index().merge(df_ppt_info, how='left', on='gameID')

# %%
df_build_phase_means
# Out:
#                                         gameID  rep  timeAbsolute  \
# 0    0581-6a290675-ac2d-4446-a181-3d3e545c534e    0  1.660175e+12
# 1    0581-6a290675-ac2d-4446-a181-3d3e545c534e    1  1.660176e+12
# 2    0581-6a290675-ac2d-4446-a181-3d3e545c534e    2  1.660176e+12
# 3    0581-6a290675-ac2d-4446-a181-3d3e545c534e    3  1.660176e+12
# 4    1199-27a29656-1dbe-4aeb-9305-8dbd12e55839    0  1.660175e+12
# ..                                         ...  ...           ...
# 103  9165-a89fbce3-5cb1-4b1e-8ef8-b546d032ad92    3  1.660174e+12
# 104  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec    0  1.660174e+12
# 105  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec    1  1.660174e+12
# 106  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec    2  1.660174e+12
# 107  9839-2624e9ad-e118-4082-95a1-7254dd7e29ec    3  1.660174e+12
#
#      timeRelative  trial_start_time  relative_time  n_resets  trial_index  \
# 0        71372.25      1.660175e+12       16162.00      0.25          4.5
# 1       142439.25      1.660176e+12       15106.50      0.25          8.5
# 2       212196.75      1.660176e+12       13441.00      0.00         12.5
# 3       278197.00      1.660176e+12       14364.25      0.00         16.5
# 4       182851.75      1.660175e+12       16134.50      0.00          4.5
# ..            ...               ...            ...       ...          ...
# 103     273196.00      1.660174e+12        8886.75      0.00         16.5
# 104     190427.00      1.660173e+12       34682.00      0.25          4.5
# 105     293171.50      1.660174e+12       56373.25      0.50          8.5
# 106     478933.00      1.660174e+12       10865.00      0.00         12.5
# 107     548034.75      1.660174e+12       14522.75      0.00         16.5
#
#      time_elapsed  trial_num  trial_duration  trial_duration_min rotation_name
# 0        66886.25        1.5        16161.75            0.269363           q_2
# 1       138007.00        5.5        15106.25            0.251771           q_2
# 2       207840.50        9.5        13441.00            0.224017           q_2
# 3       273834.00       13.5        14364.00            0.239400           q_2
# 4       183518.50        1.5        16134.25            0.268904           r_1
# ..            ...        ...             ...                 ...           ...
# 103     273772.25       13.5         8886.50            0.148108           p_2
# 104     190593.75        1.5        34681.75            0.578029           p_2
# 105     293433.25        5.5        56372.75            0.939546           p_2
# 106     479252.50        9.5        10864.50            0.181075           p_2
# 107     548419.50       13.5        14522.50            0.242042           p_2
#
# [108 rows x 13 columns]

# %% [markdown]
# ### Resets

# %%
# what is the overall variation in build performance?

# %%
sns.barplot(data = df_build_phase_means,
            y = 'n_resets',
            x = 'rep')
plt.title('mean number of resets across trials')
# Out:
# Text(0.5, 1.0, 'mean number of resets across trials')

# %%
sns.lineplot(data = df_build_phase_means,
            y = 'n_resets',
            x = 'rep',
            hue= 'gameID')
plt.title('mean number of resets across trials')
plt.legend([],[], frameon=False)

# %%
sns.histplot(df_build_means.n_resets)
plt.title('mean number of resets in trial for each ppt')
# Out:
# Text(0.5, 1.0, 'mean number of resets in trial for each ppt')

# %% [markdown]
# ### Build time

# %%
sns.lineplot(data = df_build_phase_means,
            y = 'trial_duration',
            x = 'rep',
            hue= 'gameID')
plt.title('mean build time across reps by ppt')
plt.legend([],[], frameon=False)

# %%
sns.barplot(data = df_build_phase_means,
            y = 'trial_duration',
            x = 'rep')

plt.title('mean build time across reps')
# Out:
# Text(0.5, 1.0, 'mean build time across reps')

# %%
# what's the variation across people?

sns.histplot(data = df_build_means,
            x = 'trial_duration')

plt.title('mean ppt build time')
# Out:
# Text(0.5, 1.0, 'mean ppt build time')

# %% [markdown]
# ### What explains this variation?

# %% [markdown]
# #### Are some chunks harder than others?

# %%
three_composites = pd.read_csv('../../stimuli/block_utils/ambiguous/df_stims_pre_post_run_0.csv')

# %%
three_composites[['tower_id_tall','tower_A_tall_id','tower_B_tall_id','tower_A_wide_id','tower_B_wide_id']]
# Out:
#    tower_id_tall tower_A_tall_id tower_B_tall_id tower_A_wide_id  \
# 0  talls_111_127        tall_111        tall_127        wide_011
# 1  talls_102_122        tall_102        tall_122        wide_025
# 2  talls_101_114        tall_101        tall_114        wide_019
#
#   tower_B_wide_id
# 0        wide_015
# 1        wide_010
# 2        wide_008

# %%
# ordered first by tall/ wide, then by composite in which they appear
part_order_tall_wide = \
              ['tall_111', 'tall_127',
              'tall_102', 'tall_122',
              'tall_101', 'tall_114',
              'wide_011', 'wide_015',
              'wide_025', 'wide_010',
              'wide_019', 'wide_008']

# ordered first by composite in which they appear, then by tall/ wide
part_order_composites = \
              ['tall_111', 'tall_127',
               'wide_011', 'wide_015',
               'tall_102', 'tall_122',
               'wide_025', 'wide_010',
               'tall_101', 'tall_114',
               'wide_019', 'wide_008']

part_order = part_order_composites

# %%
plt.figure(figsize = (6,4))
sns.barplot(data = df_build_part_means,
            y = 'n_resets',
            x = 'chunk_id',
            order = part_order)
plt.xticks(rotation = 45)
plt.title('mean number of resets across parts')
# Out:
# Text(0.5, 1.0, 'mean number of resets across parts')

# %%
plt.figure(figsize = (6,4))
sns.barplot(data = df_build_part_means,
            y = 'trial_duration',
            x = 'chunk_id',
            order = part_order)
plt.xticks(rotation = 45)
plt.title('mean build time across parts')
# Out:
# Text(0.5, 1.0, 'mean build time across parts')

# %%
fig, axs = plt.subplots(1, 12, figsize=(14,5))

for i, part in enumerate(part_order):
    show_part_subplot(part, axs[i])

# %% [markdown]
# #### Rotation

# %%
sns.barplot(data = df_build_phase_means,
            y = 'trial_duration',
            x = 'rotation_name',
            order=rotation_order)

plt.title('mean build time across rotations')
# Out:
# Text(0.5, 1.0, 'mean build time across rotations')

# %%
df_meta[['rotation_name','rotation']].iloc[3]['rotation']
# Out:
# {'build_wide': 'talls_111_127',
#  'build_tall': 'talls_101_114',
#  'novel': 'talls_102_122'}

# %% [markdown]
# ### How does building performance relate to zipping performance?
#
# Do the better builders have larger pre-post differences? (specifically for compatible trials?)
# Do the worse builders have larger pre-post differences? (specifically for compatible trials?)
# Do the most improving builders have larger pre-post differences? (specifically for compatible trials?)

# %%
df_build_means_condensed = df_build_means[['gameID', 'trial_duration', 'n_resets']].rename(columns = {'trial_duration':'build_duration'})

# %%
# need a dataframe with mean building performance and diffs.
df_build_zip_performance =  ppt_phase_compatibility_diffs.merge(df_build_means_condensed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-403-4e83c4b69844> in <module>
#       1 # need a dataframe with mean building performance and diffs.
# ----> 2 df_build_zip_performance =  ppt_phase_compatibility_diffs.merge(df_build_means_condensed)
#
# NameError: name 'ppt_phase_compatibility_diffs' is not defined

# %%
sns.swarmplot(data = df_build_zip_performance,
            hue = 'build_duration',
            y = 'diff_response_correct',
            x = 'compatibility')
# plt.legend([],[], frameon=False)
plt.legend(bbox_to_anchor=(1,1))

# %%
sns.swarmplot(data = df_build_zip_performance,
            hue = 'build_duration',
            y = 'diff_rt',
            x = 'compatibility')
# plt.legend([],[], frameon=False)
plt.ylim(-2000,2500)
plt.legend(bbox_to_anchor=(1,1))

# %%
sns.relplot(data = df_build_zip_performance,
                col = 'compatibility',
                y = 'diff_response_correct',
                x = 'build_duration')

# %% [markdown]
# ### individual block placements

# %%
df_block_placements

# %% [markdown]
# ### resets

# %%
df_resets.columns
# Out:
# Index(['_id', 'experimentName', 'iterationName', 'workerID', 'gameID',
#        'studyLocation', 'n_blocks_when_reset', 'trial_start_time',
#        'relative_time', 'datatype', 'stimURL', 'stimulus', 'stimId',
#        'chunk_id', 'rep', 'condition', 'chunk_type', 'n_block', 'n_resets'],
#       dtype='object')

# %%
import blockworld_utils as utils

# %%
# [utils.draw_world(utils.worldify(w)) for w in df_block_placements.blocks]

# %%
df_survey
# Out:
#                          _id       rt  \
# 0   62c7231dedff9c124677507b  24152.6
# 1   62c7237dedff9c12467750b9  12181.4
# 2   62c723a4edff9c12467750d7   4539.6
# 3   62c725d4edff9c12467751de  27195.9
# 4   62c72914edff9c1246775293  17166.0
# 5   62c743baedff9c1246776052  28329.8
# 6   62c743bfedff9c1246776064  13076.2
# 7   62c743f9edff9c1246776129  11426.3
# 8   62c74454edff9c124677623c  30378.2
# 9   62c744a1edff9c12467762f6  34629.4
# 10  62c744a1edff9c12467762f8  18813.5
# 11  62c744cbedff9c124677635e  31060.4
# 12  62c745e1edff9c12467765e0  69388.3
# 13  62c7460fedff9c124677663c  17490.4
# 14  62c74619edff9c124677664c  29112.7
# 15  62c74669edff9c12467766a0  54328.1
# 16  62c746e8edff9c1246776749  34460.7
# 17  62c74736edff9c12467767bb  23843.4
# 18  62c74771edff9c12467767f3  13761.4
# 19  62c747d5edff9c1246776834   7959.7
# 20  62c747e6edff9c124677683f  14207.3
# 21  62c74861edff9c1246776871  17226.4
# 22  62c7489bedff9c1246776887  45166.8
# 23  62c7497eedff9c12467768d0  10183.4
#
#                                              response   trial_type  \
# 0   {'technical': 'No', 'confused': 'No', 'comment...  survey-text
# 1   {'technical': 'No', 'confused': 'No', 'comment...  survey-text
# 2   {'technical': '', 'confused': '', 'comments': ''}  survey-text
# 3   {'technical': 'No', 'confused': 'No', 'comment...  survey-text
# 4   {'technical': 'o', 'confused': 'no', 'comments...  survey-text
# 5   {'technical': '', 'confused': '', 'comments': ''}  survey-text
# 6   {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 7   {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 8   {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 9   {'technical': 'no', 'confused': 'In part two, ...  survey-text
# 10  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 11  {'technical': 'No', 'confused': 'No', 'comment...  survey-text
# 12  {'technical': 'No issues at all', 'confused': ...  survey-text
# 13  {'technical': 'no', 'confused': '', 'comments'...  survey-text
# 14  {'technical': 'None at all.', 'confused': 'No,...  survey-text
# 15  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 16  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 17  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 18  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 19  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 20  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 21  {'technical': 'no', 'confused': 'no', 'comment...  survey-text
# 22  {'technical': '', 'confused': 'It took me a mo...  survey-text
# 23  {'technical': 'No', 'confused': 'No', 'comment...  survey-text
#
#     trial_index  time_elapsed internal_node_id              experimentName  \
# 0           176       1163160        0.0-176.0  block_construction_zipping
# 1           176       1237230        0.0-176.0  block_construction_zipping
# 2           176       1221847        0.0-176.0  block_construction_zipping
# 3           176       1723486        0.0-176.0  block_construction_zipping
# 4           176       2289173        0.0-176.0  block_construction_zipping
# 5           176       1282965        0.0-176.0  block_construction_zipping
# 6           176       1293785        0.0-176.0  block_construction_zipping
# 7           176       1363891        0.0-176.0  block_construction_zipping
# 8           176       1799297        0.0-176.0  block_construction_zipping
# 9           176       1416238        0.0-176.0  block_construction_zipping
# 10          176       1570834        0.0-176.0  block_construction_zipping
# 11          176       1462097        0.0-176.0  block_construction_zipping
# 12          176       1764971        0.0-176.0  block_construction_zipping
# 13          176       2165521        0.0-176.0  block_construction_zipping
# 14          176       1924494        0.0-176.0  block_construction_zipping
# 15          176       1883990        0.0-176.0  block_construction_zipping
# 16          176       1968114        0.0-176.0  block_construction_zipping
# 17          176       1359462        0.0-176.0  block_construction_zipping
# 18          176       2157881        0.0-176.0  block_construction_zipping
# 19          176       1476802        0.0-176.0  block_construction_zipping
# 20          176       2129930        0.0-176.0  block_construction_zipping
# 21          176       2187589        0.0-176.0  block_construction_zipping
# 22          176       1628320        0.0-176.0  block_construction_zipping
# 23          176       3086712        0.0-176.0  block_construction_zipping
#
#      iterationName                  workerID  \
# 0   pre_post_run_0  6098423a428aaf2854ad4092
# 1   pre_post_run_0  60a0067f943f8d336ec80fa1
# 2   pre_post_run_0  60dd22f2f6aa769f57e2c55b
# 3   pre_post_run_0  5e5580651ffa37588a3697c1
# 4   pre_post_run_0  5bcdb2880ba8a4000125ed43
# 5   pre_post_run_0  6102bbdba4dd279363094fca
# 6   pre_post_run_0  603bb3cfd1aca681ef60b8cd
# 7   pre_post_run_0  5d5a3cc29fe0f0001b0f44a4
# 8   pre_post_run_0  5c5d36bc034e280001644c3b
# 9   pre_post_run_0  5ed403a89542210ab77530b7
# 10  pre_post_run_0  5de20dc9db46652509d085b8
# 11  pre_post_run_0  62a8a9365e25dc79f3cd6598
# 12  pre_post_run_0  5e7fa0e918b10804bb87eb63
# 13  pre_post_run_0  5ee944d1886b7d1b8481387d
# 14  pre_post_run_0  5c0822f550d77a000164d7ce
# 15  pre_post_run_0  601b137a1e2f3c47fb566272
# 16  pre_post_run_0  5fb3d0c3f2ff18016df4934d
# 17  pre_post_run_0  606aad87b9f57a82dd447d6a
# 18  pre_post_run_0  60da1f2c84d5d4b2e46989c1
# 19  pre_post_run_0  55d39f64da14d7001295375a
# 20  pre_post_run_0  615776777c08445c8ffd8d1b
# 21  pre_post_run_0  6103ecec19120bbb47800858
# 22  pre_post_run_0  5b101257d282ff00015bdadb
# 23  pre_post_run_0  602e85c76e51baa166315eb8
#
#                                        gameID studyLocation   datatype  \
# 0   4722-34dc639d-d0a7-40e6-8974-9fcf153e34e6      Prolific  trial_end
# 1   2817-b371118e-ed53-4f8c-a570-8948cf2a0123      Prolific  trial_end
# 2   1287-eae5bf2b-2731-4660-a20e-b73b9dbe4624      Prolific  trial_end
# 3   0642-3e57e41e-831c-4209-b40a-dd7c5bde1e97      Prolific  trial_end
# 4   0006-45bd8004-9f80-4c7f-aba2-610e170754cb      Prolific  trial_end
# 5   1302-913536d2-7068-4cc3-b278-aa4be9edc302      Prolific  trial_end
# 6   1739-4e73d91f-c931-4343-bc0c-0cfaeef51060      Prolific  trial_end
# 7   3355-95b2fcf7-1cb9-4424-b7bc-57c6b15302fc      Prolific  trial_end
# 8   8700-7d224bf4-f965-4b22-8729-3ebebe3282d3      Prolific  trial_end
# 9   9984-ef648e44-23bb-4658-96f4-7be5c145c151      Prolific  trial_end
# 10  4699-730eec66-0ad7-4e54-b434-c8610d94972a      Prolific  trial_end
# 11  4280-ead48bf0-4655-4fcf-a03d-c02979850229      Prolific  trial_end
# 12  3032-ecc9bdc7-e432-45f3-8be7-f90fc7d078f6      Prolific  trial_end
# 13  0906-5a0b9cd7-8990-436f-81ff-591d1b22b6aa      Prolific  trial_end
# 14  6969-0940ee41-3585-4d88-894e-1870895fdc31      Prolific  trial_end
# 15  0914-dcc0f284-e639-4447-87e1-026ba2e543c0      Prolific  trial_end
# 16  7954-4d7090db-1dcf-45d5-96e8-3a7d1c45b4f6      Prolific  trial_end
# 17  8254-3948e275-09b8-43c1-b20b-4fda9d436463      Prolific  trial_end
# 18  4268-c220468b-9155-4984-ac4c-4b291b02662f      Prolific  trial_end
# 19  1326-2d711841-9503-4517-a5a8-fa407689c7bf      Prolific  trial_end
# 20  1674-5ebdf7bc-0224-4237-8873-fd0fe12cceca      Prolific  trial_end
# 21  1308-5cfe6ba2-ff50-4a68-801a-65a41dc516fd      Prolific  trial_end
# 22  6036-2f3c0b42-fb87-462b-b593-bd5037c097ac      Prolific  trial_end
# 23  7132-d5b59a6b-7b28-4aed-b5a1-be40d8bf4609      Prolific  trial_end
#
#                  response_key_dict
# 0   {'valid': 'z', 'invalid': 'm'}
# 1   {'valid': 'm', 'invalid': 'z'}
# 2   {'valid': 'm', 'invalid': 'z'}
# 3   {'valid': 'z', 'invalid': 'm'}
# 4   {'valid': 'm', 'invalid': 'z'}
# 5   {'valid': 'z', 'invalid': 'm'}
# 6   {'valid': 'm', 'invalid': 'z'}
# 7   {'valid': 'z', 'invalid': 'm'}
# 8   {'valid': 'm', 'invalid': 'z'}
# 9   {'valid': 'z', 'invalid': 'm'}
# 10  {'valid': 'm', 'invalid': 'z'}
# 11  {'valid': 'z', 'invalid': 'm'}
# 12  {'valid': 'z', 'invalid': 'm'}
# 13  {'valid': 'z', 'invalid': 'm'}
# 14  {'valid': 'm', 'invalid': 'z'}
# 15  {'valid': 'm', 'invalid': 'z'}
# 16  {'valid': 'm', 'invalid': 'z'}
# 17  {'valid': 'z', 'invalid': 'm'}
# 18  {'valid': 'z', 'invalid': 'm'}
# 19  {'valid': 'z', 'invalid': 'm'}
# 20  {'valid': 'm', 'invalid': 'z'}
# 21  {'valid': 'z', 'invalid': 'm'}
# 22  {'valid': 'm', 'invalid': 'z'}
# 23  {'valid': 'z', 'invalid': 'm'}

# %%
df_zip.to_csv('../results/zipping/csv/pilot_0_zipping_trials.csv')

# %%
# !! open .
# Out:
# []
